# %% [markdown]
# ### Decision Tree
# - Decision tree is the most powerful and popular tool for classification and prediction
# - A decision tree is a very specific type of probability tree that enables you to make a decision about some kind of process.
# - A Decision tree is a flowchart like tree structure
# - Used in data mining for deriving a strategy to reach a particular goal, its also widely used in machine learning
# - Classification and Regression algorithm
# - 2 types of Algorithms
#     1. Gini Index / Gini Impurity
#     2. Information Gain
#
# #### 1. Gini Index
# - Gini mean impurity. If gini is less, you will get pure data. if gini is more, then dataset is imbalance data.
# - Calculate the amount of probability of particular features(independent columns) that is classified incorrectly.
# - Formula: To find impurities in data
# - *GI = 1 - ( P(X1)^2 + P(X2)^2 + ....... + P(Xn)^2 )*
#
# #### 2. Information Gain(IG)
# - IG is used to calculate and reduction of Entropy
# - Entropy is also impurity of data.
# - Formula: To calculte Entropy
# - *Entropy = - ( P(0) log(P(0) ) + ( P(1) log(P(1) ) )*

# %% [markdown]
# ### Important Terminology related to Decision Trees
# - Root Node: It represents the entire sample and this further gets divided into two or more homogeneous sets.
# - Splitting: It is a process of dividing a node into two or more sub-nodes.
#
# - Decision Node: When a sub-node splits into further sub-nodes, then it is called the decision node.
# - Leaf / Terminal Node: Nodes do not split is called Leaf or Terminal node.
#
# - Branch / Sub-Tree: A subsection of the entire tree is called branch or sub-tree.
#
# - Parent and Child Node: A node, which is divided into sub-nodes is called a parent node of sub-nodes whereas sub-nodes are the child of a parent node.
#
#
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nagamounika5/Datasets/master/diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.shape
# Out:
# (768, 9)

# %%
X = df.drop(['Outcome'], axis = 1)
Y = df['Outcome']

# %%
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state=47)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dc1 = DecisionTreeClassifier(criterion = 'gini', max_depth = 2) # criterion = 'entropy'

# %%
dc1.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
Y_predict = dc1.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
confusion_matrix(Y_test, Y_predict)
# Out:
# array([[113,  14],
#        [ 34,  31]], dtype=int64)

# %%
Y_test.shape
# Out:
# (192,)

# %%
(102 + 38) / (102 + 38 + 25 + 27)
# Out:
# 0.7291666666666666

# %%
accuracy_score(Y_test, Y_predict)
# Out:
# 0.75

# %%
from sklearn import tree
import matplotlib.pyplot as plt

# %%
tree.plot_tree(dc1)
plt.show()
