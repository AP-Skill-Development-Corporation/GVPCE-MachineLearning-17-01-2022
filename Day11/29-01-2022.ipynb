# %% [markdown]
# ## Day Objective
# - Supervised Machine Learning
#     - Regression

# %% [markdown]
# ### Supervised Machine Learning
# - Machine will learn under supervisor.
#     - Dataset Varibales: Input / Independent variable and Output / Depenedent Variable.
# - Types of models
#     - Regerssion Models
#     - Classification Models

# %% [markdown]
# ### Regression Models
# - Linear Regression Models: It will check the linear relation between independent and dependent variables.
#
#
# 1. Simple Linear Regression: Linear relation between one independent variable and dependent variable.
#     ![linear1.JPG](attachment:linear1.JPG)

# %% [markdown]
# 2. Multiple Linear Regression: Linear relation between more than one independent variable and dependent variable.
#     ![image-2.png](attachment:image-2.png)

# %%
import numpy as np
import pandas as pd

# %%
dict1 = {'Head_Size': [1,2,3,4,5], 'Brain_Weight': [100,189,292,490,490]}
df = pd.DataFrame(dict1)
df
# Out:
#    Head_Size  Brain_Weight
# 0          1           100
# 1          2           189
# 2          3           292
# 3          4           490
# 4          5           490

# %%
# Head_SIze:      Independent / Input / Features
# Brain_Weight:   Dependent / Output / Target

# %% [markdown]
# #### Line Equation
# - Y  = mX + c
# - Y = b0 + b1 * X
#     - b0 --> Y-Intercept
#     - b1 --> Slope

# %% [markdown]
# **Slope Formula**

# %%
#          (Xi - mean(X)) * (Yi - mean(Y))
# b1  =   -----------------------------------
#                  (Xi - mean(X)) ^2

# %%
X1 = df['Head_Size']     # Input or Independent
Y1 = df['Brain_Weight']  # output or dependent

# %%
X1, np.mean(X1)
# Out:
# (0    1
#  1    2
#  2    3
#  3    4
#  4    5
#  Name: Head_Size, dtype: int64,
#  3.0)

# %%
Y1, np.mean(Y1)
# Out:
# (0    100
#  1    189
#  2    292
#  3    490
#  4    490
#  Name: Brain_Weight, dtype: int64,
#  312.2)

# %%
len(X1), len(Y1)
# Out:
# (5, 5)

# %%
numerator = 0
denominator = 0

for i in range(len(X1)):
    numerator += ( X1[i] - np.mean(X1) ) * ( Y1[i] - np.mean(Y1) )
    denominator += ( X1[i] - np.mean(X1) )**2
    
b1 = numerator / denominator
print(b1)# Slope
# Out:
# 108.1

# %% [markdown]
# **Intercept Formula**

# %%
# b0 = mean(Y1) - b1 * mean(X1)

# %%
b0 = np.mean(Y1) - (b1 * np.mean(X1))
b0 # intercept
# Out:
# -12.099999999999966

# %% [markdown]
# **Line Equation Formula**

# %%
# Y = b0 + b1*X
Y_predict = b0 + (b1 * X1)
Y_predict
# Out:
# 0     96.0
# 1    204.1
# 2    312.2
# 3    420.3
# 4    528.4
# Name: Head_Size, dtype: float64

# %%
Y1
# Out:
# 0    100
# 1    189
# 2    292
# 3    490
# 4    490
# Name: Brain_Weight, dtype: int64

# %% [markdown]
# ### Apply Linear Regression Model

# %% [markdown]
# **Steps to apply**
# - step1: load dataset
# - step2: Divide the columns as independent varibles and dependent variables
# - step3: Split the dateset for traing and testing
# - step4: import required model
# - step5: fit the model and Predict the values
# - step6: Check the Accuracy

# %%
# step1: load dataset
df
# Out:
#    Head_Size  Brain_Weight
# 0          1           100
# 1          2           189
# 2          3           292
# 3          4           490
# 4          5           490

# %%
# step2: Divide the columns as independent varibles and dependent variables
X1 = df[['Head_Size']] 
Y1 = df['Brain_Weight']

# %%
# step4: import required model
from sklearn.linear_model import LinearRegression

# %%
lin_reg = LinearRegression()

# %%
# step5: fit the model and Predict the values
lin_reg.fit(X1, Y1) # training
# Out:
# LinearRegression()

# %%
Y_predict1 = lin_reg.predict(X1)
Y_predict1
# Out:
# array([ 96. , 204.1, 312.2, 420.3, 528.4])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X1, Y1, color = 'c', label = 'Oroginal values')
plt.plot(X1, Y_predict1, color = 'purple', label = 'Actual values')
plt.legend()
plt.show()

# %%
y_predict

# %%
import sklearn.datasets

# %%
print(dir(sklearn.datasets))
# Out:
# ['__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '_base', '_california_housing', '_covtype', '_kddcup99', '_lfw', '_olivetti_faces', '_openml', '_rcv1', '_samples_generator', '_species_distributions', '_svmlight_format_fast', '_svmlight_format_io', '_twenty_newsgroups', 'clear_data_home', 'dump_svmlight_file', 'fetch_20newsgroups', 'fetch_20newsgroups_vectorized', 'fetch_california_housing', 'fetch_covtype', 'fetch_kddcup99', 'fetch_lfw_pairs', 'fetch_lfw_people', 'fetch_olivetti_faces', 'fetch_openml', 'fetch_rcv1', 'fetch_species_distributions', 'get_data_home', 'load_boston', 'load_breast_cancer', 'load_diabetes', 'load_digits', 'load_files', 'load_iris', 'load_linnerud', 'load_sample_image', 'load_sample_images', 'load_svmlight_file', 'load_svmlight_files', 'load_wine', 'make_biclusters', 'make_blobs', 'make_checkerboard', 'make_circles', 'make_classification', 'make_friedman1', 'make_friedman2', 'ma
# ...

# %%
from sklearn.datasets import load_boston

# %%
boston = load_boston()
boston
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
# ...

# %%
df2 = pd.DataFrame(boston.data, columns = boston.feature_names)
df2.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
boston.DESCR
# Out:
# ".. _boston_dataset:\n\nBoston house prices dataset\n---------------------------\n\n**Data Set Characteristics:**  \n\n    :Number of Instances: 506 \n\n    :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.\n\n    :Attribute Information (in order):\n        - CRIM     per capita crime rate by town\n        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.\n        - INDUS    proportion of non-retail business acres per town\n        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n        - NOX      nitric oxides concentration (parts per 10 million)\n        - RM       average number of rooms per dwelling\n        - AGE      proportion of owner-occupied units built prior to 1940\n        - DIS      weighted distances to five Boston employment centres\n        - RAD      index of accessibility to radial highways\n        - TAX      full-value property-tax rate per $10,0
# ...

# %%
df2['Target'] = boston.target

# %%
df2.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  Target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %%
X2 = df2[['RM']]   # Independent variable
Y2 = df2['Target']  # Dependent variable

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg2 = LinearRegression()

# %%
lin_reg2.fit(X2, Y2) ## Training
# Out:
# LinearRegression()

# %%
Y_predict2 = lin_reg2.predict(X2) ## Testing
Y_predict2
# Out:
# array([25.17574577, 23.77402099, 30.72803225, 29.02593787, 30.38215211,
#        23.85593997, 20.05125842, 21.50759586, 16.5833549 , 19.97844155,
#        23.3735282 , 20.02395209, 18.93169901, 19.47782555, 20.81583557,
#        18.43108302, 19.35039603, 19.85101202, 14.99048582, 17.45715736,
#        16.02812625, 19.6234593 , 21.23453259, 18.23993873, 19.25027283,
#        16.29208741, 18.23993873, 20.36983223, 24.44757706, 26.07685456,
#        17.32972783, 20.59738496, 19.48692766, 17.22050253, 20.81583557,
#        19.33219181, 18.49479778, 18.57671676, 19.63256141, 25.35778795,
#        29.26259271, 26.95065703, 21.48028953, 21.86257811, 20.57007863,
#        17.04756245, 17.99418179, 20.21509638, 14.47166561, 16.31939374,
#        19.60525508, 20.98877564, 24.5932108 , 19.92382889, 18.9225969 ,
#        31.31056723, 23.42814085, 27.36935404, 21.26183891, 19.27757916,
#        17.58458688, 19.63256141, 24.09259481, 26.87784015, 29.99076143,
# ...

# %%
lin_reg2.predict([[7.147]])
# Out:
# array([30.38215211])

# %%
X2.head()
# Out:
#       RM
# 0  6.575
# 1  6.421
# 2  7.185
# 3  6.998
# 4  7.147

# %%
Y2[:5]
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: Target, dtype: float64
